# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df_train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df_train.shape
# Out:
# (1460, 81)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
num_df = df_train.select_dtypes(include=['int64', 'float64'])
cat_df = df_train.select_dtypes(include = 'object')

# %% [markdown]
# # Numerical variable analysis

# %%
num_df.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# ### Analysing the target variable

# %%
target = num_df['SalePrice']

# %%
target.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
target.hist()
plt.show()

# %% [markdown]
# ### Discrete numerical variables

# %%
dis_col = [col for col in num_df.columns if num_df[col].nunique()<50]
dis_col
# Out:
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold']

# %%
for col in dis_col:
    print(col)
    print(num_df[col].value_counts())
    print()
# Out:
# MSSubClass
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: MSSubClass, dtype: int64
#
# OverallQual
# 5     397
# 6     374
# 7     319
# 8     168
# 4     116
# 9      43
# 3      20
# 10     18
# 2       3
# 1       2
# Name: OverallQual, dtype: int64
#
# OverallCond
# 5    821
# 6    252
# 7    205
# 8     72
# 4     57
# 3     25
# 9     22
# 2      5
# 1      1
# Name: OverallCond, dtype: int64
#
# LowQualFinSF
# 0      1434
# 80        3
# 360       2
# 392       1
# 528       1
# 515       1
# 514       1
# 513       1
# 481       1
# 479       1
# 473       1
# 420       1
# 397       1
# 390       1
# 53        1
# 384       1
# 371       1
# 234       1
# 232       1
# 205       1
# 156       1
# 144       1
# 120       1
# 572       1
# Name: LowQualFinSF, dtype: int64
#
# BsmtFullBath
# 0    856
# 1    588
# 2     15
# ...

# %%
k = len(dis_col)
for col in dis_col:
    fig =plt.figure(figsize = (20,100))
    plt.subplot(k,3,1)
    num_df.groupby(col).SalePrice.count().plot.bar()
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.subplot(k,3,3)
    num_df.groupby(col).SalePrice.median().plot.bar()
    plt.xlabel(col)
    plt.ylabel('Groupwise Median')
    plt.show()

# %% [markdown]
# Certain linear trends in `SalePrice` can be observed with features such as `Garagecars`, `TotRmsAbvGrd`, `FirePlaces`, `OverallCond` and `OverallQty`. THis is in accordance with the description of the columns, as per the schema given along with the dataset.

# %% [markdown]
# ### Continuous numerical columns

# %%
cont_col = list(set(num_df.columns) - set(dis_col))
cont_col
# Out:
# ['MasVnrArea',
#  'GarageArea',
#  '2ndFlrSF',
#  'SalePrice',
#  'Id',
#  'BsmtFinSF1',
#  'LotFrontage',
#  'YearRemodAdd',
#  'OpenPorchSF',
#  'BsmtFinSF2',
#  '1stFlrSF',
#  'WoodDeckSF',
#  'BsmtUnfSF',
#  'ScreenPorch',
#  'LotArea',
#  'YearBuilt',
#  'GrLivArea',
#  'EnclosedPorch',
#  'GarageYrBlt',
#  'TotalBsmtSF']

# %% [markdown]
# ### Univariate analysis

# %%
fig, ax = plt.subplots(nrows=5,ncols=4,figsize=(20,10))
i=0
j=0
for col in cont_col:
    sns.distplot(num_df[col],ax=ax[i][j])
    plt.show()
    i = (i+1)%5
    j = (j+1)%4
# Out:
# /home/vicky/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/vicky/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...
